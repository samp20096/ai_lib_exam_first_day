# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
items = pd.read_csv(r'C:\Users\PC\Desktop\AI Course - E-Com\exam_np_pd_plt_sns\files\Items.csv')
customers = pd.read_csv(r'C:\Users\PC\Desktop\AI Course - E-Com\exam_np_pd_plt_sns\files\customers.csv')
orders = pd.read_csv(r'C:\Users\PC\Desktop\AI Course - E-Com\exam_np_pd_plt_sns\files\orders.csv')
orders_item = pd.read_csv(r'C:\Users\PC\Desktop\AI Course - E-Com\exam_np_pd_plt_sns\files\order_item.csv')

display(items.sample(n=5))
display(customers.sample(n=5))
display(orders.sample(n=5))
display(orders_item.sample(n=5))
# Out:
#     id    item_name                  item_category  item_price  \
# 31  17  Smart Watch       Televisions and Displays      312.88
# 6   28       Camera                            NaN      695.71
# 3   25    Camcorder          Photography Equipment      860.01
# 47  29       Webcam  Printers and Office Equipment     4227.36
# 8   27  Dash Camera          Photography Equipment     1283.99
#
#     stock_quantity item_brand  item_availability
# 31           685.0      Canon               True
# 6              NaN       Sony              False
# 3            870.0       Bose               True
# 47           596.0       Dell               True
# 8            550.0     Lenovo               True
#       id first_name    last_name  gender   age   nationallity joining_date  \
# 119  120     Barbey      Wayvill  Female   NaN           Peru   15/04/2021
# 182  183   Vladamir        Trott    Male  59.0          Chile   31/08/2021
# 170  171     Floris     Birdseye     NaN  36.0          India   15/05/2020
# 273  274       Pace  Crookshanks     NaN  58.0         Isreal   13/11/2022
# 431  432     Marijn        Orvis    Male  46.0  United States   22/09/2020
#
#      phone_number                       email
# 119  191-453-0721           bwayvill3b@goo.gl
# 182  871-863-4616         vtrott52@eepurl.com
# 170  789-457-4628    fbirdseye4q@gravatar.com
# 273  142-923-5063  pcrookshanks7l@t-online.de
# 431  833-255-1456            morvisbz@ibm.com
#      order_id  customer_id      delivery_address  delivery_days  order_date  \
# 120       121        119.0  328 Southridge Drive            NaN  2023-01-02
# 427       428         59.0   50 Westridge Center            4.0  2023-09-08
# 573       574        351.0        6 Spenser Road            3.0  2023-10-06
# 370       371          5.0       6944 6th Street            NaN  2023-04-11
# 379       380          NaN    6742 Golf Junction            4.0  2023-12-24
#
#     payment_method order_source
# 120      GIFT_CARD      WEBSITE
# 427    CREDIT_CARD        STORE
# 573      GIFT_CARD      WEBSITE
# 370      GIFT_CARD      WEBSITE
# 379      GIFT_CARD        STORE
#       id  order_id  item_id  quantity
# 840  841       318     42.0         1
# 529  530        50      3.0         1
# 221  222       344     30.0         2
# 323  324       448     34.0         2
# 974  975       509     47.0         9

# %% [markdown]
# # ניתוח מידע

# %%
# 1. 
print(f'Average price of items = {items['item_price'].mean()}')

# 2. 
grouped_orders_item = orders_item.groupby(by='order_id')['quantity'].sum().reset_index()
most_buyer = grouped_orders_item.sort_values(by='quantity', ascending=False).head(1)
merged_orders = most_buyer.merge(orders, how='inner')['customer_id'].reset_index()
print(f'Top customer: {merged_orders['customer_id']}')
# Out:
# Average price of items = 2222.0825999999997
# Top customer: 0    98.0
# Name: customer_id, dtype: float64

# %% [markdown]
# # מחקר והצגה בגרפים

# %%
items_copy = items.copy()
customer_copy = customers.copy()
orders_copy = orders.copy()
orders_item_copy = orders_item.copy()

items_copy.dropna()
customer_copy.dropna()
orders_copy.dropna()
orders_item_copy.dropna()
# Out:
#        id  order_id  item_id  quantity
# 0       1       337     10.0         2
# 1       2       430     27.0         6
# 2       3       430     36.0         2
# 3       4       508     46.0         1
# 4       5       229     27.0         2
# ..    ...       ...      ...       ...
# 995   996       594     24.0         2
# 996   997       330     32.0         8
# 997   998       472     10.0         3
# 998   999       222     29.0         1
# 999  1000       337     16.0         1
#
# [960 rows x 4 columns]

# %%
# 1. 
sns.countplot(data=customers, x='gender')
plt.xticks(rotation=45)
plt.show()

# 2. 
sns.countplot(data=customers, x='nationallity')
plt.xticks(rotation=45)
plt.show()
